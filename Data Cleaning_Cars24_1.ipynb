# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt

import pickle
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\techno\OneDrive\Data Trained\Flip Robo (Batch 1836)\Car Price Prediction\Scraped Data\cars24.csv")

# %%
df
# Out:
#       Unnamed: 0             Brand Model                           Variant  \
# 0              0    2017 Maruti Alto 800                        LXI Manual
# 1              1        2020 Maruti Alto                        LXI Manual
# 2              2        2020 Maruti Alto                        VXI Manual
# 3              3  2018 Hyundai Grand i10             MAGNA 1.2 VTVT Manual
# 4              4  2016 Hyundai Grand i10            SPORTS 1.2 VTVT Manual
# ...          ...                     ...                               ...
# 4424        4424  2017 Hyundai Grand i10  SPORTZ (O) 1.2 AT VTVT Automatic
# 4425        4425  2015 Hyundai Grand i10       MAGNA 1.2 KAPPA VTVT Manual
# 4426        4426        2013 Hyundai i10    SPORTZ 1.2 AT KAPPA2 Automatic
# 4427        4427  2015 Hyundai Grand i10       MAGNA 1.2 KAPPA VTVT Manual
# 4428        4428                RESERVED            2017 Hyundai Grand i10
#
# ...

# %%
df.drop(columns='Unnamed: 0', inplace=True)

# %%
df['Brand Model'].loc[0][0:4]
# Out:
# '2017'

# %%
df['Brand Model'].loc[0][5:]
# Out:
# 'Maruti Alto 800'

# %%
df.shape
# Out:
# (4429, 8)

# %%
for i in range(df.shape[0]):
    df['Manufacturing Year'].loc[i] = df['Brand Model'].loc[i][0:4]
    df['Brand Model'].loc[i] = df['Brand Model'].loc[i][5:]

# %%
df
# Out:
#             Brand Model                           Variant Manufacturing Year  \
# 0       Maruti Alto 800                        LXI Manual               2017
# 1           Maruti Alto                        LXI Manual               2020
# 2           Maruti Alto                        VXI Manual               2020
# 3     Hyundai Grand i10             MAGNA 1.2 VTVT Manual               2018
# 4     Hyundai Grand i10            SPORTS 1.2 VTVT Manual               2016
# ...                 ...                               ...                ...
# 4424  Hyundai Grand i10  SPORTZ (O) 1.2 AT VTVT Automatic               2017
# 4425  Hyundai Grand i10       MAGNA 1.2 KAPPA VTVT Manual               2015
# 4426        Hyundai i10    SPORTZ 1.2 AT KAPPA2 Automatic               2013
# 4427  Hyundai Grand i10       MAGNA 1.2 KAPPA VTVT Manual               2015
# 4428                VED            2017 Hyundai Grand i10               RESE
#
# ...

# %%
df.rename(columns={'Brand Model': 'Brand', 'Variant': 'Model'}, inplace=True)

# %%
df
# Out:
#                   Brand                             Model Manufacturing Year  \
# 0       Maruti Alto 800                        LXI Manual               2017
# 1           Maruti Alto                        LXI Manual               2020
# 2           Maruti Alto                        VXI Manual               2020
# 3     Hyundai Grand i10             MAGNA 1.2 VTVT Manual               2018
# 4     Hyundai Grand i10            SPORTS 1.2 VTVT Manual               2016
# ...                 ...                               ...                ...
# 4424  Hyundai Grand i10  SPORTZ (O) 1.2 AT VTVT Automatic               2017
# 4425  Hyundai Grand i10       MAGNA 1.2 KAPPA VTVT Manual               2015
# 4426        Hyundai i10    SPORTZ 1.2 AT KAPPA2 Automatic               2013
# 4427  Hyundai Grand i10       MAGNA 1.2 KAPPA VTVT Manual               2015
# 4428                VED            2017 Hyundai Grand i10               RESE
#
# ...

# %%
df['Model'].loc[0]
# Out:
# 'LXI Manual'

# %%
df['Variant'] = df['Brand']

# %%
for i in range(df.shape[0]):
    if 'Manual' in df['Model'].loc[i]:
        df['Variant'].loc[i] = 'Manual'
        df['Model'].loc[i] = df['Model'].loc[i].replace('Manual','')
    elif 'Automatic' in df['Model'].loc[i]:
        df['Variant'].loc[i] = 'Automatic'
        df['Model'].loc[i] = df['Model'].loc[i].replace('Automatic','')
    else:
        df['Variant'].loc[i] = 'NaN'

# %%
df['Model'].loc[0].replace('Manual','')
# Out:
# 'LXI '

# %%
df.columns
# Out:
# Index(['Brand', 'Model', 'Manufacturing Year', 'Fuel Type',
#        'Driver Kilometers', 'Number of Owners', 'Location', 'Car Price',
#        'Variant'],
#       dtype='object')

# %%
col = ['Brand', 'Model', 'Variant', 'Manufacturing Year', 'Fuel Type','Driver Kilometers', 'Number of Owners', 'Location', 'Car Price']

# %%
df = df.reindex(columns=col)

# %%
df
# Out:
#                   Brand                    Model    Variant  \
# 0       Maruti Alto 800                     LXI      Manual
# 1           Maruti Alto                     LXI      Manual
# 2           Maruti Alto                     VXI      Manual
# 3     Hyundai Grand i10          MAGNA 1.2 VTVT      Manual
# 4     Hyundai Grand i10         SPORTS 1.2 VTVT      Manual
# ...                 ...                      ...        ...
# 4418  Hyundai Grand i10  SPORTZ (O) 1.2 AT VTVT   Automatic
# 4419  Hyundai Grand i10    MAGNA 1.2 KAPPA VTVT      Manual
# 4420        Hyundai i10    SPORTZ 1.2 AT KAPPA2   Automatic
# 4421  Hyundai Grand i10    MAGNA 1.2 KAPPA VTVT      Manual
# 4422                VED   2017 Hyundai Grand i10        NaN
#
#      Manufacturing Year  Fuel Type                 Driver Kilometers  \
# 0                  2017     Petrol                         75,118 km
# 1                  2020     Petrol                         24,682 km
# ...

# %%
from pathlib import Path  
filepath = Path("C:/Users/techno/OneDrive/Data Trained/Flip Robo (Batch 1836)/Car Price Prediction/Scraped Data/cars24A.csv")  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df.to_csv(filepath)
