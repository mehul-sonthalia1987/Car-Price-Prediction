# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt

import pickle
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\techno\OneDrive\Data Trained\Flip Robo (Batch 1836)\Car Price Prediction\Scraped Data\cars24A.csv")

# %%
df
# Out:
#       Unnamed: 0              Brand                    Model    Variant  \
# 0              0    Maruti Alto 800                     LXI      Manual
# 1              1        Maruti Alto                     LXI      Manual
# 2              2        Maruti Alto                     VXI      Manual
# 3              3  Hyundai Grand i10          MAGNA 1.2 VTVT      Manual
# 4              4  Hyundai Grand i10         SPORTS 1.2 VTVT      Manual
# ...          ...                ...                      ...        ...
# 4416        4418  Hyundai Grand i10  SPORTZ (O) 1.2 AT VTVT   Automatic
# 4417        4419  Hyundai Grand i10    MAGNA 1.2 KAPPA VTVT      Manual
# 4418        4420        Hyundai i10    SPORTZ 1.2 AT KAPPA2   Automatic
# 4419        4421  Hyundai Grand i10    MAGNA 1.2 KAPPA VTVT      Manual
# 4420        4422                VED   2017 Hyundai Grand i10        NaN
#
#      Manufacturing Year  Fuel Type                 Driver Kilometers  \
# ...

# %%
#df.reset_index()

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df
# Out:
#                   Brand                    Model    Variant  \
# 0       Maruti Alto 800                     LXI      Manual
# 1           Maruti Alto                     LXI      Manual
# 2           Maruti Alto                     VXI      Manual
# 3     Hyundai Grand i10          MAGNA 1.2 VTVT      Manual
# 4     Hyundai Grand i10         SPORTS 1.2 VTVT      Manual
# ...                 ...                      ...        ...
# 4416  Hyundai Grand i10  SPORTZ (O) 1.2 AT VTVT   Automatic
# 4417  Hyundai Grand i10    MAGNA 1.2 KAPPA VTVT      Manual
# 4418        Hyundai i10    SPORTZ 1.2 AT KAPPA2   Automatic
# 4419  Hyundai Grand i10    MAGNA 1.2 KAPPA VTVT      Manual
# 4420                VED   2017 Hyundai Grand i10        NaN
#
#      Manufacturing Year  Fuel Type                 Driver Kilometers  \
# 0                  2017     Petrol                         75,118 km
# 1                  2020     Petrol                         24,682 km
# ...

# %%
drop_index=[]
for i in range(df.shape[0]):
    if '1st Owner' in df['Fuel Type'].loc[i]:
        drop_index.append(i)
    elif '2nd Owner' in df['Fuel Type'].loc[i]:
        drop_index.append(i)

# %%
drop_index
# Out:
# [1871, 2238, 2239, 2356, 3132, 3302, 3978, 4420]

# %%
df.drop([1871, 2238, 2239, 2356, 3132, 3302, 3978, 4420], inplace=True)

# %%
#df.drop(columns=['index'], inplace=True)

# %%
df
# Out:
#                   Brand                    Model    Variant  \
# 0       Maruti Alto 800                     LXI      Manual
# 1           Maruti Alto                     LXI      Manual
# 2           Maruti Alto                     VXI      Manual
# 3     Hyundai Grand i10          MAGNA 1.2 VTVT      Manual
# 4     Hyundai Grand i10         SPORTS 1.2 VTVT      Manual
# ...                 ...                      ...        ...
# 4415  Hyundai Grand i10    MAGNA 1.2 KAPPA VTVT      Manual
# 4416  Hyundai Grand i10  SPORTZ (O) 1.2 AT VTVT   Automatic
# 4417  Hyundai Grand i10    MAGNA 1.2 KAPPA VTVT      Manual
# 4418        Hyundai i10    SPORTZ 1.2 AT KAPPA2   Automatic
# 4419  Hyundai Grand i10    MAGNA 1.2 KAPPA VTVT      Manual
#
#      Manufacturing Year Fuel Type Driver Kilometers Number of Owners  \
# 0                  2017    Petrol         75,118 km        1st Owner
# 1                  2020    Petrol         24,682 km        1st Owner
# ...

# %%
df = df.reset_index()
df.drop(columns=['index'], inplace=True)

# %%
df['Fuel Type'].value_counts()
# Out:
# Petrol          3158
# Diesel          1234
# Petrol + CNG      19
# Petrol + LPG       2
# Name: Fuel Type, dtype: int64

# %%
df
# Out:
#                   Brand                    Model    Variant  \
# 0       Maruti Alto 800                     LXI      Manual
# 1           Maruti Alto                     LXI      Manual
# 2           Maruti Alto                     VXI      Manual
# 3     Hyundai Grand i10          MAGNA 1.2 VTVT      Manual
# 4     Hyundai Grand i10         SPORTS 1.2 VTVT      Manual
# ...                 ...                      ...        ...
# 4408  Hyundai Grand i10    MAGNA 1.2 KAPPA VTVT      Manual
# 4409  Hyundai Grand i10  SPORTZ (O) 1.2 AT VTVT   Automatic
# 4410  Hyundai Grand i10    MAGNA 1.2 KAPPA VTVT      Manual
# 4411        Hyundai i10    SPORTZ 1.2 AT KAPPA2   Automatic
# 4412  Hyundai Grand i10    MAGNA 1.2 KAPPA VTVT      Manual
#
#      Manufacturing Year Fuel Type Driver Kilometers Number of Owners  \
# 0                  2017    Petrol         75,118 km        1st Owner
# 1                  2020    Petrol         24,682 km        1st Owner
# ...

# %%
#import locale
#locale.atof(df['Car Price'].loc[0][1:])

# %%
for i in range(df.shape[0]):
    df['Car Price'].loc[i] = int((df['Car Price'].loc[i][1:]).replace(',',''))

# %%
for i in range(df.shape[0]):
    df['Driver Kilometers'].loc[i] = (df['Driver Kilometers'].loc[i]).replace('km','')
    df['Driver Kilometers'].loc[i] = int((df['Driver Kilometers'].loc[i]).replace(',',''))

# %%
#df['Driver Kilometers'].loc[0][1:]

# %%
df['Number of Owners'].value_counts()
# Out:
# 1st Owner    3477
# 2nd Owner     844
# 3rd Owner      84
# 4th Owner       8
# Name: Number of Owners, dtype: int64

# %%
df
# Out:
#                   Brand                    Model    Variant  \
# 0       Maruti Alto 800                     LXI      Manual
# 1           Maruti Alto                     LXI      Manual
# 2           Maruti Alto                     VXI      Manual
# 3     Hyundai Grand i10          MAGNA 1.2 VTVT      Manual
# 4     Hyundai Grand i10         SPORTS 1.2 VTVT      Manual
# ...                 ...                      ...        ...
# 4408  Hyundai Grand i10    MAGNA 1.2 KAPPA VTVT      Manual
# 4409  Hyundai Grand i10  SPORTZ (O) 1.2 AT VTVT   Automatic
# 4410  Hyundai Grand i10    MAGNA 1.2 KAPPA VTVT      Manual
# 4411        Hyundai i10    SPORTZ 1.2 AT KAPPA2   Automatic
# 4412  Hyundai Grand i10    MAGNA 1.2 KAPPA VTVT      Manual
#
#      Manufacturing Year Fuel Type Driver Kilometers Number of Owners  \
# 0                  2017    Petrol             75118        1st Owner
# 1                  2020    Petrol             24682        1st Owner
# ...

# %%
df['Location'].value_counts()
# Out:
# Delhi NCR        821
# Mumbai           669
# Chennai          657
# Pune             626
# Bengaluru        441
# ['Ahmedabad']    384
# Jaipur           329
# Kolkata          278
# Hyderabad        128
# Delhi             80
# Name: Location, dtype: int64

# %%
for i in range(df.shape[0]):
    df['Location'].loc[i] = (df['Location'].loc[i]).replace("['Ahmedabad']",'Ahmedabad')
    #df['Location'].loc[i] = (df['Location'].loc[i]).replace(']','')

# %%
df['Location'].value_counts()
# Out:
# Delhi NCR    821
# Mumbai       669
# Chennai      657
# Pune         626
# Bengaluru    441
# Ahmedabad    384
# Jaipur       329
# Kolkata      278
# Hyderabad    128
# Delhi         80
# Name: Location, dtype: int64

# %%
df
# Out:
#                   Brand                    Model    Variant  \
# 0       Maruti Alto 800                     LXI      Manual
# 1           Maruti Alto                     LXI      Manual
# 2           Maruti Alto                     VXI      Manual
# 3     Hyundai Grand i10          MAGNA 1.2 VTVT      Manual
# 4     Hyundai Grand i10         SPORTS 1.2 VTVT      Manual
# ...                 ...                      ...        ...
# 4408  Hyundai Grand i10    MAGNA 1.2 KAPPA VTVT      Manual
# 4409  Hyundai Grand i10  SPORTZ (O) 1.2 AT VTVT   Automatic
# 4410  Hyundai Grand i10    MAGNA 1.2 KAPPA VTVT      Manual
# 4411        Hyundai i10    SPORTZ 1.2 AT KAPPA2   Automatic
# 4412  Hyundai Grand i10    MAGNA 1.2 KAPPA VTVT      Manual
#
#      Manufacturing Year Fuel Type Driver Kilometers Number of Owners  \
# 0                  2017    Petrol             75118        1st Owner
# 1                  2020    Petrol             24682        1st Owner
# ...

# %%
df.dtypes
# Out:
# Brand                 object
# Model                 object
# Variant               object
# Manufacturing Year    object
# Fuel Type             object
# Driver Kilometers     object
# Number of Owners      object
# Location              object
# Car Price             object
# dtype: object

# %%
price = df['Car Price'].value_counts()

# %%
price_object=[]
object_loc=[]
for i in range(df.shape[0]):
    if type(df['Car Price'].loc[i]) == object:
        price_object.append(df['Car Price'].loc[i])
        object_loc.append(i)

# %%
data_type=[]
for i in range(df.shape[0]):
    data_type.append(type(df['Car Price'].loc[i]))

# %%
#data_type
# Out:
# [int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
# ...

# %%
data_type_set = set(data_type)

# %%
data_type_set
# Out:
# {int}

# %%
df['Car Price'].loc[0]
# Out:
# 310199

# %%
price_object=[]
object_loc=[]
for i in range(df.shape[0]):
    if type(df['Driver Kilometers'].loc[i]) == object:
        price_object.append(df['Driver Kilometers'].loc[i])
        object_loc.append(i)

# %%
price_object
# Out:
# []

# %%
data_type=[]
for i in range(df.shape[0]):
    data_type.append(type(df['Car Price'].loc[i]))

# %%
data_type_set = set(data_type)

# %%
data_type_set
# Out:
# {int}

# %%
df['New'] = 0

# %%
df.dtypes
# Out:
# Brand                 object
# Model                 object
# Variant               object
# Manufacturing Year    object
# Fuel Type             object
# Driver Kilometers     object
# Number of Owners      object
# Location              object
# Car Price             object
# New                    int64
# dtype: object

# %%
for i in range(df.shape[0]):
    df['New'].loc[i] = df['Driver Kilometers'].loc[i]

# %%
df.dtypes
# Out:
# Brand                 object
# Model                 object
# Variant               object
# Manufacturing Year    object
# Fuel Type             object
# Driver Kilometers     object
# Number of Owners      object
# Location              object
# Car Price             object
# New                    int64
# dtype: object

# %%
df['New_Price'] = 0

# %%
for i in range(df.shape[0]):
    df['New_Price'].loc[i] = df['Car Price'].loc[i]

# %%
df.dtypes
# Out:
# Brand                 object
# Model                 object
# Variant               object
# Manufacturing Year    object
# Fuel Type             object
# Driver Kilometers     object
# Number of Owners      object
# Location              object
# Car Price             object
# New                    int64
# New_Price              int64
# dtype: object

# %%
Owners_encode = {
    '1st Owner':1,
    '2nd Owner':2,
    '3rd Owner':3,
    '4th Owner':4
}

# %%
df['Number of Owners'] = df['Number of Owners'].map(Owners_encode)

# %%
df
# Out:
#                   Brand                    Model    Variant  \
# 0       Maruti Alto 800                     LXI      Manual
# 1           Maruti Alto                     LXI      Manual
# 2           Maruti Alto                     VXI      Manual
# 3     Hyundai Grand i10          MAGNA 1.2 VTVT      Manual
# 4     Hyundai Grand i10         SPORTS 1.2 VTVT      Manual
# ...                 ...                      ...        ...
# 4408  Hyundai Grand i10    MAGNA 1.2 KAPPA VTVT      Manual
# 4409  Hyundai Grand i10  SPORTZ (O) 1.2 AT VTVT   Automatic
# 4410  Hyundai Grand i10    MAGNA 1.2 KAPPA VTVT      Manual
# 4411        Hyundai i10    SPORTZ 1.2 AT KAPPA2   Automatic
# 4412  Hyundai Grand i10    MAGNA 1.2 KAPPA VTVT      Manual
#
#      Manufacturing Year Fuel Type Driver Kilometers  Number of Owners  \
# 0                  2017    Petrol             75118                 1
# 1                  2020    Petrol             24682                 1
# ...

# %%
df.drop(columns=['Driver Kilometers', 'Car Price'], inplace=True)

# %%
df.rename(columns={'New': 'Driver Kilometers', 'New_Price': 'Car Price'}, inplace=True)

# %%
col = ['Brand', 'Model', 'Variant', 'Manufacturing Year', 'Fuel Type','Driver Kilometers', 'Number of Owners', 'Location', 'Car Price']

# %%
df = df.reindex(columns=col)

# %%
df
# Out:
#                   Brand                    Model    Variant  \
# 0       Maruti Alto 800                     LXI      Manual
# 1           Maruti Alto                     LXI      Manual
# 2           Maruti Alto                     VXI      Manual
# 3     Hyundai Grand i10          MAGNA 1.2 VTVT      Manual
# 4     Hyundai Grand i10         SPORTS 1.2 VTVT      Manual
# ...                 ...                      ...        ...
# 4408  Hyundai Grand i10    MAGNA 1.2 KAPPA VTVT      Manual
# 4409  Hyundai Grand i10  SPORTZ (O) 1.2 AT VTVT   Automatic
# 4410  Hyundai Grand i10    MAGNA 1.2 KAPPA VTVT      Manual
# 4411        Hyundai i10    SPORTZ 1.2 AT KAPPA2   Automatic
# 4412  Hyundai Grand i10    MAGNA 1.2 KAPPA VTVT      Manual
#
#      Manufacturing Year Fuel Type  Driver Kilometers  Number of Owners  \
# 0                  2017    Petrol              75118                 1
# 1                  2020    Petrol              24682                 1
# ...

# %%
df.dtypes
# Out:
# Brand                 object
# Model                 object
# Variant               object
# Manufacturing Year    object
# Fuel Type             object
# Driver Kilometers      int64
# Number of Owners       int64
# Location              object
# Car Price              int64
# dtype: object

# %%
df.duplicated().sum()
# Out:
# 44

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#df['Variant'].value_counts()

# %%
#df['Fuel Type'].value_counts()

# %% [raw]
# Variant_encode = {
#     'Manual':0,
#     'Automatic':1
# }
#
# Fuel_encode = {
#     'Petrol':0,
#     'Diesel':1,
#     'Petrol + CNG':2,
#     'Petrol + LPG':3
# }

# %%
#df['Variant'] = df['Variant'].map(Variant_encode)
#df['Fuel Type'] = df['Fuel Type'].map(Fuel_encode)

# %%
#Import library:
#from sklearn.preprocessing import LabelEncoder
#le = LabelEncoder()
#df['Location'] = le.fit_transform(df['Location'])

# %%
from pathlib import Path  
filepath = Path("C:/Users/techno/OneDrive/Data Trained/Flip Robo (Batch 1836)/Car Price Prediction/Scraped Data/cars24cleaned.csv")  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df.to_csv(filepath)
